# %% [markdown]
# # 07 Evaluate Linear Probe from a Trained Checkpoint

# %%
from src.experiments.notebook_api import load_cfg, build_trainer_from_checkpoint, build_loaders, run_linear_probe

cfg = load_cfg('configs/cifar10.yaml')
checkpoint_path = 'outputs/checkpoints/cifar10_full_sdd_last.pt'
trainer = build_trainer_from_checkpoint(cfg, checkpoint_path)
train_loader, test_loader = build_loaders(cfg)
acc = run_linear_probe(trainer, train_loader, test_loader, cfg)
acc
