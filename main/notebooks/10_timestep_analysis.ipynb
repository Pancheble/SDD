# %% [markdown]
# # 10 Timestep Analysis

# %%
import matplotlib.pyplot as plt
from src.experiments.notebook_api import load_cfg, run_timestep_sweep

cfg = load_cfg('configs/cifar10.yaml')
sweep = [(0.05, 0.45), (0.10, 0.60), (0.15, 0.70), (0.20, 0.80)]
results = run_timestep_sweep(cfg, sweep)
results

# %%
ax = results.plot(x='t_min', y=['fid', 'linear_probe_acc'], figsize=(8, 4), title='Timestep gate sweep')
ax.grid(True)
plt.show()
